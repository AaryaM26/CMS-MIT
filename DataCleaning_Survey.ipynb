# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\om\\Documents'

# %%
df=pd.read_excel('C:\\Users\\om\\Documents\\Data Cleaning.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1               Timestamp  \
# 0           0             0 2018-01-18 13:18:11.055
# 1           1             1 2018-01-18 13:20:23.542
# 2           2             2 2018-01-18 13:22:58.706
# 3           3             3 2018-01-18 13:23:12.070
# 4           4             4 2018-01-18 13:29:01.150
#
#                     1.\tName 2.\tGender 3.\tClass/Course   4.\tAge  \
# 0              Soniya Sharma     Female            MCA II       23
# 1   Ayodhya Pandurang Jadhav     Female            MCA II       22
# 2             Shrijeet Patil       Male            MCA II       22
# 3                     Heena      Female            MCA II       21
# 4               Arati Dubule     Female            MCA II       22
#
#             sim  \
# 0          bsnl
# 1        Airtel
# 2          bsnl
# 3  Reliance Jio
# 4          Idea
#
#   6.\tWhich language do you prefer to chat/message using WhatsApp?  \
# 0                            English, Marathi, hindi
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Timestamp', '1.\tName', '2.\tGender',
#        '3.\tClass/Course ', '4.\tAge', 'sim',
#        '6.\tWhich language do you prefer to chat/message using WhatsApp?',
#        '7.\tHow many WhatsApp groups do you have?',
#        '8.\tAverage number of users in each group',
#        '9.\tHow much time do you spend on whatsApp(in Hours(Per day))?',
#        '10.DataUsage', '11.\tPer day overall data consumption? ( MB)',
#        '12.\tNumber of persons you connect/contact regularly through Whatsapp',
#        '13.\tWhat best describes your usage of Whatsapp?',
#        '14.\tWhich features do you use?',
#        '15.\tAre you dissatisfied with any of Whatsapp's features?',
#        '16.\tWhat feature would you like to see added to Whatsapp?',
#        '17.\tWhat level of security, implemented in Whatsapp, do you require?',
#        'Apart from using Whatsapp on your phone, do you use the app on another device?',
# ...

# %%
df.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
df.drop(['Unnamed: 0.1'], axis=1,inplace=True)

# %%
df.head()
# Out:
#                 Timestamp                   1.\tName 2.\tGender  \
# 0 2018-01-18 13:18:11.055              Soniya Sharma     Female
# 1 2018-01-18 13:20:23.542   Ayodhya Pandurang Jadhav     Female
# 2 2018-01-18 13:22:58.706             Shrijeet Patil       Male
# 3 2018-01-18 13:23:12.070                     Heena      Female
# 4 2018-01-18 13:29:01.150               Arati Dubule     Female
#
#   3.\tClass/Course   4.\tAge           sim  \
# 0            MCA II       23          bsnl
# 1            MCA II       22        Airtel
# 2            MCA II       22          bsnl
# 3            MCA II       21  Reliance Jio
# 4            MCA II       22          Idea
#
#   6.\tWhich language do you prefer to chat/message using WhatsApp?  \
# 0                            English, Marathi, hindi
# 1                                   English, Marathi
# 2                            English, Marathi, hindi
# 3                                   English, Marathi
# ...

# %%
df.rename(columns={'20.\tOverall, how satisfied are you with WhatsApp?': 'Overall, how satisfied are you with WhatsApp?'}, inplace=True)

# %%
df1=df.columns[20]

# %%
df[df1]
# Out:
# 0            Very satisfied
# 1                   neutral
# 2      Moderately satisfied
# 3            Very satisfied
# 4      Moderately satisfied
#                ...
# 101    Moderately satisfied
# 102                 neutral
# 103          Very satisfied
# 104      Slightly satisfied
# 105          Very satisfied
# Name: Overall, how satisfied are you with WhatsApp?, Length: 106, dtype: object

# %%
df[df1].unique()
# Out:
# array(['Very satisfied', 'neutral', 'Moderately satisfied',
#        'Slightly dissatisfied', 'Slightly satisfied', 'Very dissatisfied'],
#       dtype=object)

# %%
df1 = pd.DataFrame(df[df1])

# %%
df1.isna().sum()
# Out:
# Overall, how satisfied are you with WhatsApp?    0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Overall, how satisfied are you with WhatsApp?    0
# dtype: int64

# %%
df1.replace(to_replace='Very satisfied',value=6,inplace=True)
df1.replace(to_replace='Moderately satisfied',value=5,inplace=True)
df1.replace(to_replace='Slightly dissatisfied',value=4,inplace=True)
df1.replace(to_replace='neutral',value=3,inplace=True)
df1.replace(to_replace='Slightly satisfied',value=2,inplace=True)
df1.replace(to_replace='Very dissatisfied',value=1,inplace=True)

# %%
df1
# Out:
#      Overall, how satisfied are you with WhatsApp?
# 0                                                6
# 1                                                3
# 2                                                5
# 3                                                6
# 4                                                5
# ..                                             ...
# 101                                              5
# 102                                              3
# 103                                              6
# 104                                              2
# 105                                              6
#
# [106 rows x 1 columns]

# %%
df1.describe()
# Out:
#        Overall, how satisfied are you with WhatsApp?
# count                                     106.000000
# mean                                        4.000000
# std                                         1.499206
# min                                         1.000000
# 25%                                         3.000000
# 50%                                         4.500000
# 75%                                         5.000000
# max                                         6.000000
